# %%
import time
import graphviz
import pandas as pd
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_graphviz
import sklearn.metrics
from sklearn import tree
from sklearn.metrics import accuracy_score

# %%
start_time = time.time()

# %%
df = pd.read_csv('PREPARED.csv',sep=",")

# %%
df
# Out:
#       AGE GENDER  LUNG DISEASE  HEART DISEASE  GASTRIC DISEASE LOCALITY  \
# 0      51      F             1              0                0     CITY
# 1      45      M             1              1                1     CITY
# 2      21      F             0              1                0     CITY
# 3      56      M             0              1                0  VILLAGE
# 4      41      F             1              0                1     CITY
# 5      15      M             1              0                1     CITY
# 6      12      M             0              1                0  VILLAGE
# 7      51      F             0              1                1  VILLAGE
# 8      45      M             1              0                0     CITY
# 9      12      F             0              1                1     CITY
# 10     45      M             1              1                0     CITY
# 11     84      F             1              0                1  VILLAGE
# 12     45      F             0              1                0     CITY
# 13     26      M             0              1                1     CITY
# 14     54      M             1              0                1  VILLAGE
# 15     63      F             1              1                0  VILLAGE
# 16     65      F             0              0                1     CITY
# 17     58      M             1              0                1  VILLAGE
# 18     45      M             0              0                0     CITY
# 19     12      F             1              1                1  VILLAGE
# 20     63      F             1              1                0     CITY
# 21     52      F             0              0                1  VILLAGE
# 22     15      M             1              1                0     CITY
# 23     96      M             0              1                1  VILLAGE
# 24     41      F             1              0                1     CITY
# 25     12      M             0              1                0  VILLAGE
# 26     52      F             1              0                0  VILLAGE
# 27     20      M             1              1                1     CITY
# 28     30      F             1              0                0  VILLAGE
# 29     41      M             0              1                1     CITY
# ...   ...    ...           ...            ...              ...      ...
# 3586   42      F             1              0                0  VILLAGE
# 3587   23      F             0              1                0     CITY
# 3588   23      F             0              1                0  VILLAGE
# 3589   27      F             0              1                0     CITY
# 3590   28      M             1              0                0  VILLAGE
# 3591   27      M             0              0                0  VILLAGE
# 3592   22      M             1              0                1  VILLAGE
# 3593   25      F             1              0                0     CITY
# 3594   22      F             0              1                0     CITY
# 3595   41      M             1              1                0  VILLAGE
# 3596   51      F             1              0                0  VILLAGE
# 3597   27      M             0              0                1  VILLAGE
# 3598   54      F             0              0                0     CITY
# 3599   22      M             1              1                0     CITY
# 3600   43      M             0              0                1  VILLAGE
# 3601   40      F             0              1                0  VILLAGE
# 3602   40      M             0              0                0     CITY
# 3603   24      F             1              1                1     CITY
# 3604   70      M             0              1                1  VILLAGE
# 3605   40      F             0              0                1  VILLAGE
# 3606   43      F             1              0                0     CITY
# 3607   45      M             0              1                0     CITY
# 3608   49      M             0              0                1     CITY
# 3609   21      F             1              1                0  VILLAGE
# 3610   47      F             1              0                1     CITY
# 3611   22      M             1              0                1     CITY
# 3612   68      M             0              1                1     CITY
# 3613   31      F             0              0                0  VILLAGE
# 3614   53      F             1              0                0  VILLAGE
# 3615   25      F             1              1                0  VILLAGE
#
#          STATUS  AFFECTED
# 0      DISEASED         0
# 1      DISEASED         1
# 2      DISEASED         1
# 3     RECOVERED         1
# 4      DISEASED         0
# 5      DISEASED         0
# 6     RECOVERED         1
# 7      DISEASED         1
# 8      DISEASED         0
# 9      DISEASED         1
# 10    RECOVERED         1
# 11    RECOVERED         0
# 12     DISEASED         1
# 13    RECOVERED         1
# 14     DISEASED         0
# 15    RECOVERED         1
# 16    RECOVERED         0
# 17     DISEASED         0
# 18     DISEASED         0
# 19    RECOVERED         1
# 20    RECOVERED         1
# 21     DISEASED         0
# 22     DISEASED         1
# 23    RECOVERED         1
# 24     DISEASED         0
# 25    RECOVERED         1
# 26     DISEASED         0
# 27    RECOVERED         1
# 28     DISEASED         0
# 29    RECOVERED         1
# ...         ...       ...
# 3586   DISEASED         1
# 3587  RECOVERED         0
# 3588   DISEASED         0
# 3589   DISEASED         0
# 3590   DISEASED         1
# 3591   DISEASED         0
# 3592  RECOVERED         1
# 3593  RECOVERED         0
# 3594   DISEASED         1
# 3595   DISEASED         0
# 3596  RECOVERED         1
# 3597  RECOVERED         0
# 3598  RECOVERED         0
# 3599  RECOVERED         0
# 3600  RECOVERED         0
# 3601   DISEASED         1
# 3602  RECOVERED         0
# 3603   DISEASED         1
# 3604   DISEASED         1
# 3605  RECOVERED         0
# 3606  RECOVERED         0
# 3607  RECOVERED         1
# 3608  RECOVERED         0
# 3609   DISEASED         1
# 3610   DISEASED         0
# 3611   DISEASED         1
# 3612   DISEASED         1
# 3613  RECOVERED         0
# 3614  RECOVERED         0
# 3615   DISEASED         1
#
# [3616 rows x 8 columns]

# %%
df_numeric_only = df._get_numeric_data()

# %%
df_numeric_only
# Out:
#       AGE  LUNG DISEASE  HEART DISEASE  GASTRIC DISEASE  AFFECTED
# 0      51             1              0                0         0
# 1      45             1              1                1         1
# 2      21             0              1                0         1
# 3      56             0              1                0         1
# 4      41             1              0                1         0
# 5      15             1              0                1         0
# 6      12             0              1                0         1
# 7      51             0              1                1         1
# 8      45             1              0                0         0
# 9      12             0              1                1         1
# 10     45             1              1                0         1
# 11     84             1              0                1         0
# 12     45             0              1                0         1
# 13     26             0              1                1         1
# 14     54             1              0                1         0
# 15     63             1              1                0         1
# 16     65             0              0                1         0
# 17     58             1              0                1         0
# 18     45             0              0                0         0
# 19     12             1              1                1         1
# 20     63             1              1                0         1
# 21     52             0              0                1         0
# 22     15             1              1                0         1
# 23     96             0              1                1         1
# 24     41             1              0                1         0
# 25     12             0              1                0         1
# 26     52             1              0                0         0
# 27     20             1              1                1         1
# 28     30             1              0                0         0
# 29     41             0              1                1         1
# ...   ...           ...            ...              ...       ...
# 3586   42             1              0                0         1
# 3587   23             0              1                0         0
# 3588   23             0              1                0         0
# 3589   27             0              1                0         0
# 3590   28             1              0                0         1
# 3591   27             0              0                0         0
# 3592   22             1              0                1         1
# 3593   25             1              0                0         0
# 3594   22             0              1                0         1
# 3595   41             1              1                0         0
# 3596   51             1              0                0         1
# 3597   27             0              0                1         0
# 3598   54             0              0                0         0
# 3599   22             1              1                0         0
# 3600   43             0              0                1         0
# 3601   40             0              1                0         1
# 3602   40             0              0                0         0
# 3603   24             1              1                1         1
# 3604   70             0              1                1         1
# 3605   40             0              0                1         0
# 3606   43             1              0                0         0
# 3607   45             0              1                0         1
# 3608   49             0              0                1         0
# 3609   21             1              1                0         1
# 3610   47             1              0                1         0
# 3611   22             1              0                1         1
# 3612   68             0              1                1         1
# 3613   31             0              0                0         0
# 3614   53             1              0                0         0
# 3615   25             1              1                0         1
#
# [3616 rows x 5 columns]

# %%
x = df_numeric_only.values[:, 0:4]
y = df_numeric_only.values[:,4]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.30)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2531, 4)
# (1085, 4)
# (2531,)
# (1085,)

# %%
features = list(df.columns[:4])

# %%
#from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier(criterion = "entropy", random_state = 1, splitter='best')
classifier = classifier.fit(x_train,y_train)

# %%
predictions = classifier.predict(x_test)

# %%
print(sklearn.metrics.confusion_matrix(y_test, predictions))
# Out:
# [[566  36]
#  [ 37 446]]

# %%
print("accuracy of training dataset is{:.2f}".format(classifier.score(x_train,y_train)))
print("accuracy of test dataset is {:.2f}".format(classifier.score(x_test,y_test)))
# Out:
# accuracy of training dataset is0.94
# accuracy of test dataset is 0.93

# %%
print("Error rate is",1- accuracy_score(y_test, predictions, normalize = True))
# Out:
# Error rate is 0.06728110599078341

# %%
print("sensitivity is", sklearn.metrics.recall_score(y_test, predictions,labels=None, average =  'micro', sample_weight=None))
# Out:
# sensitivity is 0.9327188940092166

# %%
print("specificity is", 1 - sklearn.metrics.recall_score(y_test, predictions,labels=None, average =  'micro', sample_weight=None))
# Out:
# specificity is 0.06728110599078341
